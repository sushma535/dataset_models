# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import os
os.chdir('C:/Users/raja/Documents/retaildataset')

# %%
encoding_list = ['ascii', 'big5', 'big5hkscs', 'cp037', 'cp273', 'cp424', 'cp437', 'cp500', 'cp720', 'cp737'
                 , 'cp775', 'cp850', 'cp852', 'cp855', 'cp856', 'cp857', 'cp858', 'cp860', 'cp861', 'cp862'
                 , 'cp863', 'cp864', 'cp865', 'cp866', 'cp869', 'cp874', 'cp875', 'cp932', 'cp949', 'cp950'
                 , 'cp1006', 'cp1026', 'cp1125', 'cp1140', 'cp1250', 'cp1251', 'cp1252', 'cp1253', 'cp1254'
                 , 'cp1255', 'cp1256', 'cp1257', 'cp1258', 'euc_jp', 'euc_jis_2004', 'euc_jisx0213', 'euc_kr'
                 , 'gb2312', 'gbk', 'gb18030', 'hz', 'iso2022_jp', 'iso2022_jp_1', 'iso2022_jp_2'
                 , 'iso2022_jp_2004', 'iso2022_jp_3', 'iso2022_jp_ext', 'iso2022_kr', 'latin_1', 'iso8859_2'
                 , 'iso8859_3', 'iso8859_4', 'iso8859_5', 'iso8859_6', 'iso8859_7', 'iso8859_8', 'iso8859_9'
                 , 'iso8859_10', 'iso8859_11', 'iso8859_13', 'iso8859_14', 'iso8859_15', 'iso8859_16', 'johab'
                 , 'koi8_r', 'koi8_t', 'koi8_u', 'kz1048', 'mac_cyrillic', 'mac_greek', 'mac_iceland', 'mac_latin2'
                 , 'mac_roman', 'mac_turkish', 'ptcp154', 'shift_jis', 'shift_jis_2004', 'shift_jisx0213', 'utf_32'
                 , 'utf_32_be', 'utf_32_le', 'utf_16', 'utf_16_be', 'utf_16_le', 'utf_7', 'utf_8', 'utf_8_sig']

for encoding in encoding_list:
    worked = True
    try:
        df = pd.read_csv('data.csv', encoding='utf8', nrows=200)
    except:
        worked = False
    if worked:
        print(encoding, ':\n', df)
# Out:
# ascii :
#      InvoiceNo StockCode                          Description  Quantity  \
# 0      536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 195    536388     22469                HEART OF WICKER SMALL        12
# 196    536388     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 197    536389     22941         CHRISTMAS LIGHTS 10 REINDEER         6
# 198    536389     21622     VINTAGE UNION JACK CUSHION COVER         8
# 199    536389     21791   VINTAGE HEADS AND TAILS CARD GAME         12
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df
# Out:
#     InvoiceNo StockCode                          Description  Quantity  \
# 0      536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 195    536388     22469                HEART OF WICKER SMALL        12
# 196    536388     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 197    536389     22941         CHRISTMAS LIGHTS 10 REINDEER         6
# 198    536389     21622     VINTAGE UNION JACK CUSHION COVER         8
# 199    536389     21791   VINTAGE HEADS AND TAILS CARD GAME         12
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55       17850  United Kingdom
# 1  12/1/2010 8:26       3.39       17850  United Kingdom
# 2  12/1/2010 8:26       2.75       17850  United Kingdom
# 3  12/1/2010 8:26       3.39       17850  United Kingdom
# 4  12/1/2010 8:26       3.39       17850  United Kingdom

# %%
df.tail()
# Out:
#     InvoiceNo StockCode                         Description  Quantity  \
# 195    536388     22469               HEART OF WICKER SMALL        12
# 196    536388     22242       5 HOOK HANGER MAGIC TOADSTOOL        12
# 197    536389     22941        CHRISTMAS LIGHTS 10 REINDEER         6
# 198    536389     21622    VINTAGE UNION JACK CUSHION COVER         8
# 199    536389     21791  VINTAGE HEADS AND TAILS CARD GAME         12
#
#          InvoiceDate  UnitPrice  CustomerID         Country
# 195   12/1/2010 9:59       1.65       16250  United Kingdom
# 196   12/1/2010 9:59       1.65       16250  United Kingdom
# 197  12/1/2010 10:03       8.50       12431       Australia
# 198  12/1/2010 10:03       4.95       12431       Australia
# 199  12/1/2010 10:03       1.25       12431       Australia

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df.columns = df.columns.str.upper()

# %%
df.columns
# Out:
# Index(['INVOICENO', 'STOCKCODE', 'DESCRIPTION', 'QUANTITY', 'INVOICEDATE',
#        'UNITPRICE', 'CUSTOMERID', 'COUNTRY'],
#       dtype='object')

# %%
df.rename(columns = {'INVOICEDATE' : 'DATE AND TIME'})
# Out:
#     INVOICENO STOCKCODE                          DESCRIPTION  QUANTITY  \
# 0      536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365     71053                  WHITE METAL LANTERN         6
# 2      536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ..        ...       ...                                  ...       ...
# 195    536388     22469                HEART OF WICKER SMALL        12
# 196    536388     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 197    536389     22941         CHRISTMAS LIGHTS 10 REINDEER         6
# 198    536389     21622     VINTAGE UNION JACK CUSHION COVER         8
# 199    536389     21791   VINTAGE HEADS AND TAILS CARD GAME         12
#
#        DATE AND TIME  UNITPRICE  CUSTOMERID         COUNTRY
# ...

# %%
df.isnull()
# Out:
#      INVOICENO  STOCKCODE  DESCRIPTION  QUANTITY  INVOICEDATE  UNITPRICE  \
# 0        False      False        False     False        False      False
# 1        False      False        False     False        False      False
# 2        False      False        False     False        False      False
# 3        False      False        False     False        False      False
# 4        False      False        False     False        False      False
# ..         ...        ...          ...       ...          ...        ...
# 195      False      False        False     False        False      False
# 196      False      False        False     False        False      False
# 197      False      False        False     False        False      False
# 198      False      False        False     False        False      False
# 199      False      False        False     False        False      False
#
#      CUSTOMERID  COUNTRY
# 0         False    False
# 1         False    False
# ...

# %%
df.isnull().any()
# Out:
# INVOICENO      False
# STOCKCODE      False
# DESCRIPTION    False
# QUANTITY       False
# INVOICEDATE    False
# UNITPRICE      False
# CUSTOMERID     False
# COUNTRY        False
# dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (200, 8)

# %%
df.describe()
# Out:
#          QUANTITY   UNITPRICE    CUSTOMERID
# count  200.000000  200.000000    200.000000
# mean    19.435000    3.571000  15709.230000
# std     50.224179    3.543118   1862.393243
# min     -1.000000    0.380000  12431.000000
# 25%      3.000000    1.650000  14688.000000
# 50%      6.000000    2.550000  15670.000000
# 75%     12.000000    4.250000  17850.000000
# max    432.000000   27.500000  18074.000000

# %%
df.plot(kind='scatter', x='UNITPRICE', y='QUANTITY')
plt.show()

# %%
df.plot(kind='box')
plt.show()

# %%
df.corr()
# Out:
#             QUANTITY  UNITPRICE  CUSTOMERID
# QUANTITY    1.000000  -0.143082   -0.040059
# UNITPRICE  -0.143082   1.000000    0.020010
# CUSTOMERID -0.040059   0.020010    1.000000

# %%
UnitPrice=pd.DataFrame(df['UNITPRICE'])
Quantity=pd.DataFrame(df['QUANTITY'])

# %%
UnitPrice
# Out:
#      UNITPRICE
# 0         2.55
# 1         3.39
# 2         2.75
# 3         3.39
# 4         3.39
# ..         ...
# 195       1.65
# 196       1.65
# 197       8.50
# 198       4.95
# 199       1.25
#
# [200 rows x 1 columns]

# %%
lm= linear_model.LinearRegression()
model= lm.fit(UnitPrice,Quantity)

# %%
model.coef_
# Out:
# array([[-2.02820409]])

# %%
model.intercept_
# Out:
# array([26.6777168])

# %%
model.score(UnitPrice,Quantity)
# Out:
# 0.02047240987741117

# %%
import numpy as np
UnitPrice_new = np.array([80])
UnitPrice_new = UnitPrice_new.reshape(-1,1)
Quantity_predict=model.predict(UnitPrice_new)
Quantity_predict
# Out:
# C:\Users\raja\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[-135.5786102]])

# %%
X=([89,77,16])
X=pd.DataFrame(X)
Y=model.predict(X)
Y=pd.DataFrame(Y)
data=pd.concat([X,Y], axis=1,keys=['UnitPrice_new','Quantity_predict'])
data
# Out:
# C:\Users\raja\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
#   UnitPrice_new Quantity_predict
#               0                0
# 0            89      -153.832447
# 1            77      -129.493998
# 2            16        -5.773549

# %%
df.plot(kind='scatter', x='UNITPRICE', y='QUANTITY')
plt.plot(UnitPrice,model.predict(Quantity),color='red', linewidth=2)
plt.scatter(UnitPrice, Quantity, color='black')
plt.show()
# Out:
# C:\Users\raja\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - QUANTITY
# Feature names seen at fit time, yet now missing:
# - UNITPRICE
#
#   warnings.warn(message, FutureWarning)
