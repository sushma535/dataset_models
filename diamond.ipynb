# %%
pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\raja\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import os
os.chdir('C:/Users/raja/Documents/retaildataset')

# %%
data = pd.read_csv('diamonds.csv')

# %%
data
# Out:
#               id                                                url    shape  \
# 0       10086429  https://www.brilliantearth.com//loose-diamonds...    Round
# 1       10016334  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 2        9947216  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 3       10083437  https://www.brilliantearth.com//loose-diamonds...    Round
# 4        9946136  https://www.brilliantearth.com//loose-diamonds...  Emerald
# ...          ...                                                ...      ...
# 119302  10081678  https://www.brilliantearth.com//lab-diamonds-s...    Round
# 119303   9521564  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119304   9896730  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119305   9756570  https://www.brilliantearth.com//lab-diamonds-s...     Oval
# 119306   9293400  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
#
# ...

# %%
data.head()
# Out:
#          id                                                url    shape  \
# 0  10086429  https://www.brilliantearth.com//loose-diamonds...    Round
# 1  10016334  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 2   9947216  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 3  10083437  https://www.brilliantearth.com//loose-diamonds...    Round
# 4   9946136  https://www.brilliantearth.com//loose-diamonds...  Emerald
#
#    price  carat        cut color clarity report     type         date_fetched
# 0    400   0.30  Very Good     J     SI2    GIA  natural  2020-11-29 12-26 PM
# 1    400   0.31      Ideal     I     SI1    GIA  natural  2020-11-29 12-26 PM
# 2    400   0.30      Ideal     I     VS2    GIA  natural  2020-11-29 12-26 PM
# 3    400   0.30      Ideal     I     SI2    GIA  natural  2020-11-29 12-26 PM
# 4    400   0.30      Ideal     I     SI1    GIA  natural  2020-11-29 12-26 PM

# %%
data.tail()
# Out:
#               id                                                url    shape  \
# 119302  10081678  https://www.brilliantearth.com//lab-diamonds-s...    Round
# 119303   9521564  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119304   9896730  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119305   9756570  https://www.brilliantearth.com//lab-diamonds-s...     Oval
# 119306   9293400  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
#
#          price  carat          cut color clarity report type  \
# 119302   99040   5.71  Super Ideal     D    VVS2   GCAL  lab
# 119303  107330  15.32    Very Good     G     SI2    IGI  lab
# 119304  110110  10.05        Ideal     D     SI2    IGI  lab
# 119305  126030  10.33         Fair     D     VS2    IGI  lab
# 119306  141710  10.25         Good     E     VS1    IGI  lab
#
#                date_fetched
# 119302  2020-11-29 12-26 PM
# 119303  2020-11-29 12-26 PM
# 119304  2020-11-29 12-26 PM
# ...

# %%
data.isna()
# Out:
#            id    url  shape  price  carat    cut  color  clarity  report  \
# 0       False  False  False  False  False  False  False    False   False
# 1       False  False  False  False  False  False  False    False   False
# 2       False  False  False  False  False  False  False    False   False
# 3       False  False  False  False  False  False  False    False   False
# 4       False  False  False  False  False  False  False    False   False
# ...       ...    ...    ...    ...    ...    ...    ...      ...     ...
# 119302  False  False  False  False  False  False  False    False   False
# 119303  False  False  False  False  False  False  False    False   False
# 119304  False  False  False  False  False  False  False    False   False
# 119305  False  False  False  False  False  False  False    False   False
# 119306  False  False  False  False  False  False  False    False   False
#
#          type  date_fetched
# 0       False         False
# 1       False         False
# ...

# %%
data.shape
# Out:
# (119307, 11)

# %%
data.describe()
# Out:
#                  id         price          carat
# count  1.193070e+05  1.193070e+05  119307.000000
# mean   9.905507e+06  3.286843e+03       0.884169
# std    2.373824e+05  9.114695e+03       0.671141
# min    4.367730e+05  2.700000e+02       0.250000
# 25%    9.854352e+06  9.000000e+02       0.400000
# 50%    9.978096e+06  1.770000e+03       0.700000
# 75%    1.005433e+07  3.490000e+03       1.100000
# max    1.009225e+07  1.348720e+06      15.320000

# %%
data.plot(kind='scatter', x='price',y='carat')
plt.show()

# %%
data.plot(kind='box')
plt.show()

# %%
data.corr()
# Out:
#              id     price     carat
# id     1.000000  0.041761  0.072422
# price  0.041761  1.000000  0.555578
# carat  0.072422  0.555578  1.000000

# %%
price=pd.DataFrame(data['price'])
carat=pd.DataFrame(data['carat'])

# %%
price
# Out:
#          price
# 0          400
# 1          400
# 2          400
# 3          400
# 4          400
# ...        ...
# 119302   99040
# 119303  107330
# 119304  110110
# 119305  126030
# 119306  141710
#
# [119307 rows x 1 columns]

# %%
lm =linear_model.LinearRegression()
model=lm.fit(price,carat)

# %%
model.coef_
# Out:
# array([[4.09088057e-05]])

# %%
model.intercept_
# Out:
# array([0.74970791])

# %%
model.score(price, carat)
# Out:
# 0.30866735270351064

# %%
import numpy as np
price_new = np.array([97])
price_new = price_new.reshape(-1,1)
carat_predict = model.predict(price_new)
carat_predict
# Out:
# C:\Users\raja\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[0.75367606]])

# %%
X=np.array([67,78,94])
X=pd.DataFrame(X)
Y=model.predict(X)
Y=pd.DataFrame(Y)
df=pd.concat([X,Y], axis=1,keys=['price_new','carat_predict'])
df
# Out:
# C:\Users\raja\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
#   price_new carat_predict
#           0             0
# 0        67      0.752449
# 1        78      0.752899
# 2        94      0.753553

# %%
data.plot(kind='scatter', x='price', y='carat')
plt.plot(price,model.predict(price),color='red', linewidth=2)
plt.scatter(price_new, carat_predict, color='black')
plt.plot(df)
plt.show()
